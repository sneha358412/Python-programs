# %%
num =10
print(num/1)
print("last ;ine of the program")
# Out:
# 10.0
# last ;ine of the program

# %%
try: 
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divided by Zero")
# Out:
# cannot divided by Zero

# %%
try:
    file = open("xyz.txt","r")
                
except FileNotFoundError:
    print ("file doesn't exist")
# Out:
# file doesn't exist

# %%
try:
    age=int(input("Enter the age"))
    print(age)
except TypeError:
     print("The age is 21")
# Out:
# Enter the age 21
# 21

# %%
try:
    year =int(input("Enter the year"))
    print(year)
except TypeError:
    print("The age is 2005")
# Out:
# Enter the year 2005
# 2005

# %%
try:
    name =int(input("Enter the name"))
    print(name)
except TypeError:
    print("The name is raju")
# Out:
# Enter the name raju
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 try:
# ----> 2     name =int(input("Enter the name"))
#       3     print(name)
#       4 except TypeError:
#
# ValueError: invalid literal for int() with base 10: 'raju'
