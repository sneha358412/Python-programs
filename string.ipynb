# %%
name=input("Enter the name:")
print("welcome",name)
# Out:
# Enter the name: :sneha
# welcome :sneha

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
p="deepthi"
print(p[::-3])
# Out:
# ipd

# %%
name="sneha"
def greet():
    print("Hello",name)
greet()
# Out:
# Hello sneha

# %%
name="mancherial"
def greet():
    print("Hello",name)
greet()
# Out:
# Hello mancherial

# %%
name="deepthi"
def greet():
    print("Hello",name)
greet()
# Out:
# Hello deepthi

# %%
def add (a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def add (a,b,c=0):
    return a+b+c
print (add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def add (a,b,c=0):
    return a+b+c
print (add(20,30))
print (add(20,30,40))
# Out:
# 50
# 90

# %%
def add(a,b,c=0):
    return a*b*c
print (add(10,20))
print(add(10,20,30))
# Out:
# 0
# 6000

# %%
def add ( *numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def add ( *numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30,)
add(10,20,30,40)
add(20,30,60,70,50)
# Out:
# 30
# 60
# 100
# 230

# %%
def student(*marks):
    print(sum(marks))
student(55,40,90)            
student(270,340,300)
# Out:
# 185
# 910

# %% [raw]
# print (10+20)
# print ("kavitha" + "yadav")
