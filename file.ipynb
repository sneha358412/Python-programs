# %%
name =["paint" ,"brush" ,"color"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# paint
# brush
# color

# %%
name=[9,7,4]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 9
# 7
# 4
