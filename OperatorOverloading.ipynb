# %%
name"sneha"
emailid:-gaddamsnehagoud@gmail.com
print(name)
print( email id )

# %% [markdown]
# sneha
# gaddamsnehagoud@gmail.com

# %% [markdown]
# city"mancherial"
# print(city)[1]

# %%
m

# %% [markdown]
# ##### city"godavarikani"
# print(city [-4])

# %% [markdown]
# name="sneha"
# print(name[1.4])

# %%
neha

# %% [markdown]
# name"sneha"
# print(len(name))

# %%
5

# %%
First="sneha"
Second="Goud"
print(First+""Second)

# %%
snehagoud

# %%
print("Hello"*4)

# %%
print("Hello" * 4)
# Out:
# HelloHelloHelloHello

# %%
name="sneha"
print(name.upper())
# Out:
# SNEHA

# %%
name="SNEHA"
print(name.lower())
# Out:
# sneha

# %%
s="i like to read"
print(s.replace("read" ,"write"))
# Out:
# i like to write

# %%
name=input("Enter the name")
print(" welcome" ,name )

# %%
p="python"
python([::-1])
